# %%
import pandas as pd
import numpy as np
df=pd.read_csv(r"C:\Users\MIDHAT\Downloads\autism+screening+adult\autism_adult_clean.csv")
print(df.head(10))
# Out:
#    A1_Score  A2_Score  A3_Score  A4_Score  A5_Score  A6_Score  A7_Score  \
# 0         1         1         1         1         0         0         1
# 1         1         1         0         1         0         0         0
# 2         1         1         0         1         1         0         1
# 3         1         1         0         1         0         0         1
# 4         1         0         0         0         0         0         0
# 5         1         1         1         1         1         0         1
# 6         0         1         0         0         0         0         0
# 7         1         1         1         1         0         0         0
# 8         1         1         0         0         1         0         0
# 9         1         1         1         1         0         1         1
#
#    A8_Score  A9_Score  A10_Score  ...  gender       ethnicity jundice austim  \
# 0         1         0          0  ...       f  White-European      no     no
# 1         1         0          1  ...       m          Latino      no    yes
# 2         1         1          1  ...       m          Latino     yes    yes
# 3         1         0          1  ...       f  White-European      no    yes
# 4         1         0          0  ...       f               ?      no     no
# 5         1         1          1  ...       m          Others     yes     no
# 6         1         0          0  ...       f           Black      no     no
# 7         0         1          0  ...       m  White-European      no     no
# 8         1         1          1  ...       m  White-European      no     no
# 9         1         1          0  ...       m           Asian     yes    yes
#
#    contry_of_res used_app_before result     age_desc  \
# 0  United States              no    6.0  18 and more
# 1         Brazil              no    5.0  18 and more
# 2          Spain              no    8.0  18 and more
# 3  United States              no    6.0  18 and more
# 4          Egypt              no    2.0  18 and more
# 5  United States              no    9.0  18 and more
# 6  United States              no    2.0  18 and more
# 7    New Zealand              no    5.0  18 and more
# 8  United States              no    6.0  18 and more
# 9        Bahamas              no    8.0  18 and more
#
#                    relation Class/ASD
# 0                      Self        NO
# 1                      Self        NO
# 2                    Parent       YES
# 3                      Self        NO
# 4                         ?        NO
# 5                      Self       YES
# 6                      Self        NO
# 7                    Parent        NO
# 8                      Self        NO
# 9  Health care professional       YES
#
# [10 rows x 21 columns]

# %%
df.shape
# Out:
# (704, 21)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      A1_Score  A2_Score  A3_Score  A4_Score  A5_Score  A6_Score  A7_Score  \
# 0           1         1         1         1         0         0         1
# 1           1         1         0         1         0         0         0
# 2           1         1         0         1         1         0         1
# 3           1         1         0         1         0         0         1
# 4           1         0         0         0         0         0         0
# ..        ...       ...       ...       ...       ...       ...       ...
# 699         0         1         0         1         1         0         1
# 700         1         0         0         0         0         0         0
# 701         1         0         1         1         1         0         1
# 702         1         0         0         1         1         0         1
# 703         1         0         1         1         1         0         1
#
#      A8_Score  A9_Score  A10_Score  ...  gender       ethnicity jundice  \
# 0           1         0          0  ...       f  White-European      no
# 1           1         0          1  ...       m          Latino      no
# 2           1         1          1  ...       m          Latino     yes
# 3           1         0          1  ...       f  White-European      no
# 4           1         0          0  ...       f               ?      no
# ..        ...       ...        ...  ...     ...             ...     ...
# 699         1         1          1  ...       f  White-European      no
# 700         1         0          1  ...       m        Hispanic      no
# 701         1         0          1  ...       f               ?      no
# 702         0         1          1  ...       m     South Asian      no
# 703         1         1          1  ...       f  White-European      no
#
#     austim  contry_of_res used_app_before result     age_desc relation  \
# 0       no  United States              no    6.0  18 and more     Self
# 1      yes         Brazil              no    5.0  18 and more     Self
# 2      yes          Spain              no    8.0  18 and more   Parent
# 3      yes  United States              no    6.0  18 and more     Self
# 4       no          Egypt              no    2.0  18 and more        ?
# ..     ...            ...             ...    ...          ...      ...
# 699     no         Russia              no    7.0  18 and more     Self
# 700     no         Mexico              no    3.0  18 and more   Parent
# 701     no         Russia              no    7.0  18 and more        ?
# 702     no       Pakistan              no    6.0  18 and more     Self
# 703     no         Cyprus              no    8.0  18 and more     Self
#
#     Class/ASD
# 0          NO
# 1          NO
# 2         YES
# 3          NO
# 4          NO
# ..        ...
# 699       YES
# 700        NO
# 701       YES
# 702        NO
# 703       YES
#
# [704 rows x 21 columns]>

# %%
print(df["Class/ASD"].value_counts())
#TARGET COLUMN
# Out:
# Class/ASD
# NO     515
# YES    189
# Name: count, dtype: int64

# %%
print(df.isnull().sum())
# Out:
# A1_Score           0
# A2_Score           0
# A3_Score           0
# A4_Score           0
# A5_Score           0
# A6_Score           0
# A7_Score           0
# A8_Score           0
# A9_Score           0
# A10_Score          0
# age                2
# gender             0
# ethnicity          0
# jundice            0
# austim             0
# contry_of_res      0
# used_app_before    0
# result             0
# age_desc           0
# relation           0
# Class/ASD          0
# dtype: int64

# %%
for col in df.columns:
    print(col, df[col].unique())
# Out:
# A1_Score [1 0]
# A2_Score [1 0]
# A3_Score [1 0]
# A4_Score [1 0]
# A5_Score [0 1]
# A6_Score [0 1]
# A7_Score [1 0]
# A8_Score [1 0]
# A9_Score [0 1]
# A10_Score [0 1]
# age [ 26.  24.  27.  35.  40.  36.  17.  64.  29.  33.  18.  31.  30.  34.
#   38.  42.  43.  48.  37.  55.  50.  53.  20.  28.  21. 383.  47.  32.
#   44.  nan  19.  58.  45.  22.  39.  25.  23.  54.  60.  41.  46.  56.
#   61.  59.  52.  49.  51.]
# gender <StringArray>
# ['f', 'm']
# Length: 2, dtype: str
# ethnicity <StringArray>
# [ 'White-European',          'Latino',               '?',          'Others',
#            'Black',           'Asian', 'Middle Eastern ',        'Pasifika',
#      'South Asian',        'Hispanic',         'Turkish',          'others']
# Length: 12, dtype: str
# jundice <StringArray>
# ['no', 'yes']
# Length: 2, dtype: str
# austim <StringArray>
# ['no', 'yes']
# Length: 2, dtype: str
# contry_of_res <StringArray>
# [       'United States',               'Brazil',                'Spain',
#                 'Egypt',          'New Zealand',              'Bahamas',
#               'Burundi',              'Austria',            'Argentina',
#                'Jordan',              'Ireland', 'United Arab Emirates',
#           'Afghanistan',              'Lebanon',       'United Kingdom',
#          'South Africa',                'Italy',             'Pakistan',
#            'Bangladesh',                'Chile',               'France',
#                 'China',            'Australia',               'Canada',
#          'Saudi Arabia',          'Netherlands',              'Romania',
#                'Sweden',                'Tonga',                 'Oman',
#                 'India',          'Philippines',            'Sri Lanka',
#          'Sierra Leone',             'Ethiopia',             'Viet Nam',
#                  'Iran',           'Costa Rica',              'Germany',
#                'Mexico',               'Russia',              'Armenia',
#               'Iceland',            'Nicaragua',            'Hong Kong',
#                 'Japan',              'Ukraine',           'Kazakhstan',
#         'AmericanSamoa',              'Uruguay',               'Serbia',
#              'Portugal',             'Malaysia',              'Ecuador',
#                 'Niger',              'Belgium',              'Bolivia',
#                 'Aruba',              'Finland',               'Turkey',
#                 'Nepal',            'Indonesia',               'Angola',
#            'Azerbaijan',                 'Iraq',       'Czech Republic',
#                'Cyprus']
# Length: 67, dtype: str
# used_app_before <StringArray>
# ['no', 'yes']
# Length: 2, dtype: str
# result [ 6.  5.  8.  2.  9. 10.  4.  3.  0.  1.  7.]
# age_desc <StringArray>
# ['18 and more']
# Length: 1, dtype: str
# relation <StringArray>
# ['Self', 'Parent', '?', 'Health care professional', 'Relative', 'Others']
# Length: 6, dtype: str
# Class/ASD <StringArray>
# ['NO', 'YES']
# Length: 2, dtype: str

# %%
import seaborn as sns
sns.countplot(x="Class/ASD",data=df,color="yellow")
# Out:
# <Axes: xlabel='Class/ASD', ylabel='count'>

# %%
df=df.rename(columns={'contry_of_res': 'country_of_res','jundice':'jaundice','austim':'autism','Class/ASD':'Class'})
df.head(5)
# Out:
#    A1_Score  A2_Score  A3_Score  A4_Score  A5_Score  A6_Score  A7_Score  \
# 0         1         1         1         1         0         0         1
# 1         1         1         0         1         0         0         0
# 2         1         1         0         1         1         0         1
# 3         1         1         0         1         0         0         1
# 4         1         0         0         0         0         0         0
#
#    A8_Score  A9_Score  A10_Score  ...  gender       ethnicity jaundice autism  \
# 0         1         0          0  ...       f  White-European       no     no
# 1         1         0          1  ...       m          Latino       no    yes
# 2         1         1          1  ...       m          Latino      yes    yes
# 3         1         0          1  ...       f  White-European       no    yes
# 4         1         0          0  ...       f               ?       no     no
#
#   country_of_res used_app_before result     age_desc relation Class
# 0  United States              no    6.0  18 and more     Self    NO
# 1         Brazil              no    5.0  18 and more     Self    NO
# 2          Spain              no    8.0  18 and more   Parent   YES
# 3  United States              no    6.0  18 and more     Self    NO
# 4          Egypt              no    2.0  18 and more        ?    NO
#
# [5 rows x 21 columns]

# %%
print(df["gender"].unique())
print(df["ethnicity"].unique())
print(df["country_of_res"].unique())
# Out:
# <StringArray>
# ['f', 'm']
# Length: 2, dtype: str
# <StringArray>
# [ 'White-European',          'Latino',               '?',          'Others',
#            'Black',           'Asian', 'Middle Eastern ',        'Pasifika',
#      'South Asian',        'Hispanic',         'Turkish',          'others']
# Length: 12, dtype: str
# <StringArray>
# [       'United States',               'Brazil',                'Spain',
#                 'Egypt',          'New Zealand',              'Bahamas',
#               'Burundi',              'Austria',            'Argentina',
#                'Jordan',              'Ireland', 'United Arab Emirates',
#           'Afghanistan',              'Lebanon',       'United Kingdom',
#          'South Africa',                'Italy',             'Pakistan',
#            'Bangladesh',                'Chile',               'France',
#                 'China',            'Australia',               'Canada',
#          'Saudi Arabia',          'Netherlands',              'Romania',
#                'Sweden',                'Tonga',                 'Oman',
#                 'India',          'Philippines',            'Sri Lanka',
#          'Sierra Leone',             'Ethiopia',             'Viet Nam',
#                  'Iran',           'Costa Rica',              'Germany',
#                'Mexico',               'Russia',              'Armenia',
#               'Iceland',            'Nicaragua',            'Hong Kong',
#                 'Japan',              'Ukraine',           'Kazakhstan',
#         'AmericanSamoa',              'Uruguay',               'Serbia',
#              'Portugal',             'Malaysia',              'Ecuador',
#                 'Niger',              'Belgium',              'Bolivia',
#                 'Aruba',              'Finland',               'Turkey',
#                 'Nepal',            'Indonesia',               'Angola',
#            'Azerbaijan',                 'Iraq',       'Czech Republic',
#                'Cyprus']
# Length: 67, dtype: str

# %%
df.columns = df.columns.str.strip().str.lower()
print(df.columns)
#CASE CONSISTENCY
# Out:
# Index(['a1_score', 'a2_score', 'a3_score', 'a4_score', 'a5_score', 'a6_score',
#        'a7_score', 'a8_score', 'a9_score', 'a10_score', 'age', 'gender',
#        'ethnicity', 'jaundice', 'autism', 'country_of_res', 'used_app_before',
#        'result', 'age_desc', 'relation', 'class'],
#       dtype='str')

# %%
print(df["class"].unique())
#checing if target column contains text values
# Out:
# <StringArray>
# ['NO', 'YES']
# Length: 2, dtype: str

# %%
df["class"] = df["class"].map({"YES": 1, "NO": 0})
#turning text into numeric values

# %%
print(df["class"].unique())
# Out:
# [0 1]

# %%
df["ethnicity"] = df["ethnicity"].str.strip().str.lower()
df["gender"] = df["gender"].str.strip().str.lower()
df["country_of_res"] = df["country_of_res"].str.strip()
#fix spaces and case issues

# %%
import numpy as np

df["ethnicity"] = df["ethnicity"].replace("?", np.nan)
#HANDLE MISSING VALUES

# %%
df.isnull().sum()
# Out:
# a1_score            0
# a2_score            0
# a3_score            0
# a4_score            0
# a5_score            0
# a6_score            0
# a7_score            0
# a8_score            0
# a9_score            0
# a10_score           0
# age                 2
# gender              0
# ethnicity          95
# jaundice            0
# autism              0
# country_of_res      0
# used_app_before     0
# result              0
# age_desc            0
# relation            0
# class               0
# dtype: int64

# %%
df = df.dropna(subset=["age"])

# %%
df["ethnicity"] = df["ethnicity"].fillna("unknown")
#replace missing values

# %%
df["ethnicity"] = df["ethnicity"].str.strip().str.lower()
df["ethnicity"] = df["ethnicity"].replace("others", "other")

# %%
print(df.isnull().sum())
# Out:
# a1_score           0
# a2_score           0
# a3_score           0
# a4_score           0
# a5_score           0
# a6_score           0
# a7_score           0
# a8_score           0
# a9_score           0
# a10_score          0
# age                0
# gender             0
# ethnicity          0
# jaundice           0
# autism             0
# country_of_res     0
# used_app_before    0
# result             0
# age_desc           0
# relation           0
# class              0
# dtype: int64

# %%
print(df.columns)
# Out:
# Index(['a1_score', 'a2_score', 'a3_score', 'a4_score', 'a5_score', 'a6_score',
#        'a7_score', 'a8_score', 'a9_score', 'a10_score', 'age', 'gender',
#        'ethnicity', 'jaundice', 'autism', 'country_of_res', 'used_app_before',
#        'result', 'age_desc', 'relation', 'class'],
#       dtype='str')

# %%
df = df.drop(["used_app_before"], axis=1, errors='ignore')

# %%
print(df.columns)
# Out:
# Index(['a1_score', 'a2_score', 'a3_score', 'a4_score', 'a5_score', 'a6_score',
#        'a7_score', 'a8_score', 'a9_score', 'a10_score', 'age', 'gender',
#        'ethnicity', 'jaundice', 'autism', 'country_of_res', 'result',
#        'age_desc', 'relation', 'class'],
#       dtype='str')

# %%
X = df.drop("class", axis=1)
y = df["class"]
#SEPARATING FEATURES(INPUT) AND TARGET(OUTPUT)

# %%
df.head(5)
# Out:
#    a1_score  a2_score  a3_score  a4_score  a5_score  a6_score  a7_score  \
# 0         1         1         1         1         0         0         1
# 1         1         1         0         1         0         0         0
# 2         1         1         0         1         1         0         1
# 3         1         1         0         1         0         0         1
# 4         1         0         0         0         0         0         0
#
#    a8_score  a9_score  a10_score   age gender       ethnicity jaundice autism  \
# 0         1         0          0  26.0      f  white-european       no     no
# 1         1         0          1  24.0      m          latino       no    yes
# 2         1         1          1  27.0      m          latino      yes    yes
# 3         1         0          1  35.0      f  white-european       no    yes
# 4         1         0          0  40.0      f         unknown       no     no
#
#   country_of_res  result     age_desc relation  class
# 0  United States     6.0  18 and more     Self      0
# 1         Brazil     5.0  18 and more     Self      0
# 2          Spain     8.0  18 and more   Parent      1
# 3  United States     6.0  18 and more     Self      0
# 4          Egypt     2.0  18 and more        ?      0

# %%
from sklearn.preprocessing import LabelEncoder

for col in df.columns:
    if df[col].dtype == 'object' or df[col].dtype == 'string':
        df[col] = LabelEncoder().fit_transform(df[col].astype(str))

# %%
df.dtypes
# Out:
# a1_score            int64
# a2_score            int64
# a3_score            int64
# a4_score            int64
# a5_score            int64
# a6_score            int64
# a7_score            int64
# a8_score            int64
# a9_score            int64
# a10_score           int64
# age               float64
# gender              int64
# ethnicity           int64
# jaundice            int64
# autism              int64
# country_of_res      int64
# result            float64
# age_desc            int64
# relation            int64
# class               int64
# dtype: object

# %%
df.to_csv("cleaned_autism_data.csv", index=False)
#SAVING THE FINAL CLEANED CSV FILE

# %%
#LOADING THE CLEANED FILE
import pandas as pd

df = pd.read_csv("cleaned_autism_data.csv")

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="whitegrid")

# %%
df["class"] = df["class"].map({0: "No Autism", 1: "Autism"})

# %%
#NO OF INDIVIDUALS WITHOUT AUTISM TRAITS

sns.countplot(x="class", data=df,  hue="class",  
    palette={"No Autism": "skyblue", "Autism": "red"})
plt.title("Autism Screening Outcome Distribution")
plt.show()

# %%
df["gender_label"] = df["gender"].map({0: "Female", 1: "Male"})
df["class_label"] = df["class"].map({0: "No Autism", 1: "Autism"})
#CONVERTING NUMBERS TO LABELS FOR EASY VISUALISATION

# %%
counts = df["gender_label"].value_counts()

plt.figure(figsize=(6,6))

plt.pie(
    counts,
    labels=counts.index,
    autopct='%1.1f%%',
    colors=["skyblue", "pink"],
    startangle=90
)

plt.title("Gender Distribution")

plt.show()

# %%
#CHECK IF ONE GENDER HAS HIGHER CRISIS
import seaborn as sns
import matplotlib.pyplot as plt

sns.countplot(x="gender_label", hue="class", data=df,palette={"No Autism": "skyblue", "Autism": "pink"})

plt.title("Gender vs Autism Screening Outcome")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.legend(title="Autism Status")
plt.show()

# %%
#AGE DISTRIBUTION
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(df["age"], bins=20, kde=True,color="purple")

plt.xlim(0, 100)  
plt.title("Age Distribution")
plt.xlabel("Age")
plt.ylabel("Frequency")

plt.show()

# %%
#CORRELATION HEATMAP OF ALL ATTRIBUTES
import numpy as np

numeric_df = df.select_dtypes(include=[np.number])
numeric_df = df.select_dtypes(include='number')

sns.heatmap(numeric_df.corr(), cmap="coolwarm")

plt.title("Feature Correlation Heatmap")
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("cleaned_autism_data.csv")

df["class_label"] = df["class"].map({0: "No Autism", 1: "Autism"})

plt.figure(figsize=(8,5))

sns.boxplot(
    x="class_label",
    y="age",
    data=df,
    hue="class_label",
    palette={"No Autism": "#4CAF50", "Autism": "#FF9800"}
)

plt.ylim(0, 100)  

plt.title("Age Distribution by Autism Screening Outcome")
plt.xlabel("Autism Category")
plt.ylabel("Age")

plt.show()

# %%
import matplotlib.pyplot as plt

# count values
counts = df["class_label"].value_counts()

plt.figure(figsize=(6,6))

plt.pie(
    counts,
    labels=counts.index,
    autopct='%1.1f%%',
    colors=["brown", "orange"],
    startangle=90
)

plt.title("Autism Screening Distribution")

plt.show()

# %%
df["class"] = df["class"].map({0: "No Autism", 1: "Autism"})

# %%
#OVERALL AUTISM SCREENING SCORE
df["total_score"] = df[
    ["a1_score","a2_score","a3_score","a4_score","a5_score",
     "a6_score","a7_score","a8_score","a9_score","a10_score"]
].sum(axis=1)

# %%
#AGE GROUPS
df["age_group"] = pd.cut(
    df["age"],
    bins=[0, 18, 30, 50, 100],
    labels=["Teen", "Young Adult", "Adult", "Senior"]
)

# %%
df=df.drop(columns=["class_label","gender_label"],errors='ignore')

# %%
#MODELS LEARN THE SAME DECISION BOUNDARY AND SAME PREDICTIONS SO OUTPUT ARE THE SAME

# %%
import pandas as pd

# Verify required columns exist
required_cols = {'result', 'class'}
missing = required_cols - set(df.columns)
if missing:
    raise KeyError(f"Missing expected columns in dataframe: {missing}")

# Define features X and target y
X = df.drop(columns=['result', 'class'])
y = df['class']

# Display shapes and sample data
print("Feature matrix X shape:", X.shape)
print("Target vector y shape:", y.shape)
print("\nFirst 5 rows of X:")
print(X.head())
print("\nFirst 5 values of y:")
print(y.head())
# Out:
# Feature matrix X shape: (702, 20)
# Target vector y shape: (702,)
#
# First 5 rows of X:
#    a1_score  a2_score  a3_score  a4_score  a5_score  a6_score  a7_score  \
# 0         1         1         1         1         0         0         1
# 1         1         1         0         1         0         0         0
# 2         1         1         0         1         1         0         1
# 3         1         1         0         1         0         0         1
# 4         1         0         0         0         0         0         0
#
#    a8_score  a9_score  a10_score   age  gender  ethnicity  jaundice  autism  \
# 0         1         0          0  26.0       0         10         0       0
# 1         1         0          1  24.0       1          3         0       1
# 2         1         1          1  27.0       1          3         1       1
# 3         1         0          1  35.0       0         10         0       1
# 4         1         0          0  40.0       0          9         0       0
#
#    country_of_res  age_desc  relation  total_score  age_group
# 0              64         0         5            6          3
# 1              13         0         5            5          3
# 2              56         0         3            8          3
# 3              64         0         5            6          0
# 4              22         0         0            2          0
#
# First 5 values of y:
# 0    No Autism
# 1    No Autism
# 2       Autism
# 3    No Autism
# 4    No Autism
# Name: class, dtype: str

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
y = le.fit_transform(df['class'])

# %%
#TRAIN TEST SPLIT FOR LOGISTIC REGRESSION

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,
    stratify=y,
    random_state=42
)

print("Train shape:", X_train.shape)
print("Test shape:", X_test.shape)
# Out:
# Train shape: (561, 20)
# Test shape: (141, 20)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
#MODEL TRAINING

# %%
#LOGISTIC REGRESSION
from sklearn.linear_model import LogisticRegression

log_model = LogisticRegression(max_iter=1000, random_state=42)
log_model.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression(max_iter=1000, random_state=42)

# %%
#DECISION TREE
from sklearn.tree import DecisionTreeClassifier

dt_model = DecisionTreeClassifier(random_state=42)
dt_model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
#RANDOM FOREST
from sklearn.ensemble import RandomForestClassifier

rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
                                    #PREDICTIONS

# %%
# Logistic Regression
y_pred_log = log_model.predict(X_test_scaled)
y_prob_log = log_model.predict_proba(X_test_scaled)[:, 1]

# Decision Tree
y_pred_dt = dt_model.predict(X_test)
y_prob_dt = dt_model.predict_proba(X_test)[:, 1]

# Random Forest
y_pred_rf = rf_model.predict(X_test)
y_prob_rf = rf_model.predict_proba(X_test)[:, 1]

# %%
#MTERICS
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

def evaluate_model(y_true, y_pred, y_prob):
    return {
        "Accuracy": accuracy_score(y_true, y_pred),
        "Precision": precision_score(y_true, y_pred),
        "Recall": recall_score(y_true, y_pred),
        "F1-score": f1_score(y_true, y_pred),
        "ROC-AUC": roc_auc_score(y_true, y_prob)
    }

# %%
#EVALUATION
results = {
    "Logistic Regression": evaluate_model(y_test, y_pred_log, y_prob_log),
    "Decision Tree": evaluate_model(y_test, y_pred_dt, y_prob_dt),
    "Random Forest": evaluate_model(y_test, y_pred_rf, y_prob_rf)
}

# %%
#CROSS VALIDATION 
from sklearn.model_selection import StratifiedKFold, cross_val_score

cv = StratifiedKFold(n_splits=10, shuffle=True, random_state=42)

cv_scores = cross_val_score(rf_model, X, y, cv=cv)

print("Cross-validation accuracy:", cv_scores.mean())
# Out:
# Cross-validation accuracy: 1.0

# %%
import numpy as np
print(np.unique(y, return_counts=True))
#CHECK DATASET BALANCE/IMBALANCE
# Out:
# (array([0, 1]), array([189, 513]))

# %%
import pandas as pd
import matplotlib.pyplot as plt

feat_importance = pd.Series(rf_model.feature_importances_, index=X.columns)
feat_importance.sort_values(ascending=False).plot(kind='bar', figsize=(10,5))
plt.title("Feature Importance (Random Forest)")
plt.show()

# %%
                                #SHAP IMPLEMENTATION
import shap

shap.initjs()

explainer = shap.TreeExplainer(rf_model)
shap_values = explainer.shap_values(X_test)

shap.summary_plot(shap_values[:, :, 1], X_test)
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# (()=>{var e,t,n={221(e,t,n){"use strict";var r=n(540);function a(e){var t="https://react.dev/errors/"+e;if(1<arguments.length){t+="?args[]="+encodeURIComponent(arguments[1]);for(var n=2;n<arguments.length;n++)t+="&args[]="+encodeURIComponent(arguments[n])}return"Minified React error #"+e+"; visit "+t+" for the full message or use the non-minified dev environment for full errors and additional helpful warnings."}function i(){}var o={d:{f:i,r:function(){throw Error(a(522))},D:i,C:i,L:i,m:i,X:i,S:i,M:i},p:0,findDOMNode:null},l=Symbol.for("react.portal"),u=r.__CLIENT_INTERNALS_DO_NOT_USE_OR_WARN_USERS_THEY_CANNOT_UPGRADE;function s(e,t){return"font"===e?"":"string"==typeof t?"use-credentials"===t?t:"":void 0}t.__DOM_INTERNALS_DO_NOT_USE_OR_WARN_USERS_THEY_CANNOT_UPGRADE=o,t.createPortal=function(e,t){var n=2<arguments.length&&void 0!==arguments[2]?arguments[2]:null;if(!t||1!==t.nodeType&&9!==t.nodeType&&11!==t.nodeType)throw Error(a(299));return function(e,t,n){var r=3<arguments.length&&void 0!==arguments[3]?arguments[3]:null;return{$$typeof:l,key:null==r?null:""+r,children:e,containerInfo:t,implementation:n}}(e,t,null,n)},t.flushSync=function(e){var t=u.T,n=o.p;try{if(u.T=null,o.p=2,e)return e()}finally{u.T=t,o.p=n,o.d.f()}},t.preconnect=function(e,t){"string"==typeof e&&(t=t?"string"==typeof(t=t.crossOrigin)?"use-credentials"===t?t:"":void 0:null,o.d.C(e,t))},t.prefetchDNS=function(e){"string"==typeof e&&o.d.D(e)},t.preinit=function(e,t){if("string"==typeof e&&t&&"string"==typeof t.as){var n=t.as,r=s(n,t.crossOrigin),a="string"==typeof t.integrity?t.integrity:void 0,i="string"==typeof t.fetchPriority?t.fetchPriority:void 0;"style"===n?o.d.S(e,"string"==typeof t.precedence?t.precedence:void 0,{crossOrigin:r,integrity:a,fetchPriority:i}):"script"===n&&o.d.X(e,{crossOrigin:r,integrity:a,fetchPriority:i,nonce:"string"==typeof t.nonce?t.nonce:void 0})}},t.preinitModule=function(e,t){if("string"==typeof e)if("object"==typeof t&&null!==t){if(null==t.as||"script"===t.as){var n=s(t.as,t.crossOrigin);o.d.M(e,{crossOrigin:n,integrity:"string"==typeof t.integrity?t.integrity:void 0,nonce:"string"==typeof t.nonce?t.nonce:void 0})}}else null==t&&o.d.M(e)},t.preload=function(e,t){if("string"==typeof e&&"object"==typeof t&&null!==t&&"string"==typeof t.as){var n=t.as,r=s(n,t.crossOrigin);o.d.L(e,n,{crossOrigin:r,integrity:"string"==typeof t.integrity?t.integrity:void 0,nonce:"string"==typeof t.nonce?t.nonce:void 0,type:"string"==typeof t.type?t.type:void 0,fetchPriority:"string"==typeof t.fetchPriority?t.fetchPriority:void 0,referrerPolicy:"string"==typeof t.referrerPolicy?t.referrerPolicy:void 0,imageSrcSet:"string"==typeof t.imageSrcSet?t.imageSrcSet:void 0,imageSizes:"string"==typeof t.imageSizes?t.imageSizes:void 0,media:"string"==typeof t.media?t.media:void 0})}},t.preloadModule=function(e,t){if("string"==typeof e)if(t){var n=s(t.as,t.crossOrigin);o.d.m(e,{as:"string"==typeof t.as&&"script"!==t.as?t.as:void 0,crossOrigin:n,integrity:"string"==typeof t.integrity?t.integrity:void 0})}else o.d.m(e)},t.requestFormReset=function(e){o.d.r(e)},t.unstable_batchedUpdates=function(e,t){return e(t)},t.useFormState=function(e,t,n){return u.H.useFormState(e,t,n)},t.useFormStatus=function(){return u.H.useHostTransitionStatus()},t.version="19.2.4"},247(e,t,n){"use strict";var r=n(982),a=n(540),i=n(961);function o(e){var t="https://react.dev/errors/"+e;if(1<arguments.length){t+="?args[]="+encodeURIComponent(arguments[1]);for(var n=2;n<arguments.length;n++)t+="&args[]="+encodeURIComponent(arguments[n])}return"Minified React error #"+e+"; visit "+t+" for the full message or use the non-minified dev environment for full errors and additional helpful warnings."}function l(e){return!(!e||1!==e.nodeType&&9!==e.nodeType&&11!==e.nodeType)}function u(e){var t=e,n=e;if(e.alternate)for(;t.return;)t=t.return;else{e=t;do{!!(4098&(t=e).flags)&&(n=t.return),e=t.return}while(e)}return 3===t.tag?n:null}function s(e){if(13===e.tag){var t=e.memoizedState;if(null===t&&null!== ...

# %%
                               #SHAP IMPLEMENTATION (LOCAL)
index = 0

shap.force_plot(
    explainer.expected_value[1],
    shap_values[index, :, 1],
    X_test.iloc[index],
    matplotlib=True
)

# %%
#      FEATURE REDUTION EXPERIMENT
top_features = feat_importance.sort_values(ascending=False).head(5).index

X_reduced = X[top_features]

from sklearn.model_selection import cross_val_score
scores = cross_val_score(rf_model, X_reduced, y, cv=5)

print("Reduced feature accuracy:", scores.mean())
# Out:
# Reduced feature accuracy: 1.0
